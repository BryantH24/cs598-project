# %% [markdown]
# Add Average CFB Season Weather Data to School Data

# %%
import pandas as pd
import requests
from datetime import datetime
from time import sleep

INPUT_CSV = '../../intermediate_files/schools_with_locations.csv'
OUTPUT_CSV = '../../intermediate_files/schools_with_weather.csv'
WEATHER_API_URL = 'https://archive-api.open-meteo.com/v1/archive'

# %%
def fetch_season_weather_data(latitude, longitude, start_date='2024-08-01', end_date='2024-12-31'):
    params = {
        'latitude': latitude,
        'longitude': longitude,
        'start_date': start_date,
        'end_date': end_date,
        'hourly': [
            'temperature_2m',
            'relative_humidity_2m',
            'wind_speed_10m',
            'wind_direction_10m',
            'precipitation',
            'weather_code'
        ],
        'timezone': 'America/New_York'
    }

    response = requests.get(WEATHER_API_URL, params=params)
    response.raise_for_status()
    data = response.json()

    if 'hourly' in data and data['hourly']['time']:
        temperatures = data['hourly']['temperature_2m']
        humidities = data['hourly']['relative_humidity_2m']
        wind_speeds = data['hourly']['wind_speed_10m']
        wind_directions = data['hourly']['wind_direction_10m']
        precipitations = data['hourly']['precipitation']
        weather_codes = data['hourly']['weather_code']

        daytime_data = []
        for i, time_str in enumerate(data['hourly']['time']):
            hour = datetime.fromisoformat(time_str.replace('Z', '+00:00')).hour
            if 8 <= hour <= 20:  # Only do daytime
                daytime_data.append({
                    'temperature': temperatures[i],
                    'humidity': humidities[i],
                    'wind_speed': wind_speeds[i],
                    'wind_direction': wind_directions[i],
                    'precipitation': precipitations[i],
                    'weather_code': weather_codes[i]
                })

        if daytime_data:
            # Averages
            avg_weather = {
                'avg_temperature_2m': sum(d['temperature'] for d in daytime_data) / len(daytime_data),
                'avg_humidity_2m': sum(d['humidity'] for d in daytime_data) / len(daytime_data),
                'avg_wind_speed_10m': sum(d['wind_speed'] for d in daytime_data) / len(daytime_data),
                'avg_wind_direction_10m': sum(d['wind_direction'] for d in daytime_data) / len(daytime_data),
                'total_precipitation': sum(d['precipitation'] for d in daytime_data),
                'avg_weather_code': sum(d['weather_code'] for d in daytime_data) / len(daytime_data),
                'data_points': len(daytime_data)
            }
            return avg_weather

    return None

# %%
df = pd.read_csv(INPUT_CSV)

weather_columns = [
    'avg_temperature_2m',
    'avg_humidity_2m',
    'avg_wind_speed_10m',
    'avg_wind_direction_10m',
    'total_precipitation',
    'avg_weather_code',
    'weather_data_points'
]

for col in weather_columns:
    df[col] = None

successful_requests = 0
failed_requests = 0

for idx, row in df.iterrows():
    school = row['cfb_school']
    lat = row['latitude']
    lon = row['longitude']

    if pd.isna(lat) or pd.isna(lon):
        print("Missing coordinates for", school)
        failed_requests += 1
        continue

    print("Fetching weather for", school)

    weather_data = fetch_season_weather_data(lat, lon)

    if weather_data:
        for col, value in weather_data.items():
            if col == 'data_points':
                df.at[idx, 'weather_data_points'] = value
            else:
                df.at[idx, col] = value
        successful_requests += 1
    else:
        failed_requests += 1

    sleep(5)
    print("Fetching weather for school", idx+1, "/", len(df))


    # Save every 10     
    if (idx + 1) % 10 == 0:
        print("RESULTS: ", successful_requests, failed_requests)
        df.to_csv(OUTPUT_CSV, index=False)

df.to_csv(OUTPUT_CSV, index=False)
# Out:
# Fetching weather for Abilene Christian
# Fetching weather for school 1 / 252
# Fetching weather for Air Force
# Fetching weather for school 2 / 252
# Fetching weather for Akron
# Fetching weather for school 3 / 252
# Fetching weather for Alabama
# Fetching weather for school 4 / 252
# Fetching weather for Alabama A&M
# Fetching weather for school 5 / 252
# Fetching weather for Alabama State
# Fetching weather for school 6 / 252
# Fetching weather for Albany
# Fetching weather for school 7 / 252
# Fetching weather for Alcorn State
# Fetching weather for school 8 / 252
# Fetching weather for Appalachian State
# Fetching weather for school 9 / 252
# Fetching weather for Arizona
# Fetching weather for school 10 / 252
# RESULTS:  10 0
# Fetching weather for Arizona State
# Fetching weather for school 11 / 252
# Fetching weather for Arkansas
# Fetching weather for school 12 / 252
# Fetching weather for Arkansas State
# Fetching weather for school 13 / 252
# Fetching weather for Arkansas-Pine Bluff
# Fetching weather for school 14 / 252
# Fetching weather for Army
# Fetching weather for school 15 / 252
# Fetching weather for Auburn
# Fetching weather for school 16 / 252
# Fetching weather for Austin Peay
# Fetching weather for school 17 / 252
# Fetching weather for BYU
# Fetching weather for school 18 / 252
# Fetching weather for Ball State
# Fetching weather for school 19 / 252
# Fetching weather for Baylor
# Fetching weather for school 20 / 252
# RESULTS:  20 0
# Fetching weather for Bethune Cookman
# Fetching weather for school 21 / 252
# Fetching weather for Boise State
# Fetching weather for school 22 / 252
# Fetching weather for Boston College
# Fetching weather for school 23 / 252
# Fetching weather for Bowling Green
# Fetching weather for school 24 / 252
# Fetching weather for Bryant
# Fetching weather for school 25 / 252
# Fetching weather for Bucknell
# Fetching weather for school 26 / 252
# Fetching weather for Buffalo
# Fetching weather for school 27 / 252
# Fetching weather for Cal Poly SLO
# Fetching weather for school 28 / 252
# Fetching weather for California
# Fetching weather for school 29 / 252
# Fetching weather for Campbell
# Fetching weather for school 30 / 252
# RESULTS:  30 0
# Fetching weather for Central Arkansas
# Fetching weather for school 31 / 252
# Fetching weather for Central Conn. State
# Fetching weather for school 32 / 252
# Fetching weather for Central Michigan
# Fetching weather for school 33 / 252
# Fetching weather for Charleston Southern
# Fetching weather for school 34 / 252
# Fetching weather for Charlotte
# Fetching weather for school 35 / 252
# Fetching weather for Chattanooga
# Fetching weather for school 36 / 252
# Fetching weather for Cincinnati
# Fetching weather for school 37 / 252
# Fetching weather for Citadel
# Fetching weather for school 38 / 252
# Fetching weather for Clemson
# Fetching weather for school 39 / 252
# Fetching weather for Coastal Carolina
# Fetching weather for school 40 / 252
# RESULTS:  40 0
# Fetching weather for Colgate
# Fetching weather for school 41 / 252
# Fetching weather for Colorado
# Fetching weather for school 42 / 252
# Fetching weather for Colorado State
# Fetching weather for school 43 / 252
# Fetching weather for Connecticut
# Fetching weather for school 44 / 252
# Fetching weather for Delaware
# Fetching weather for school 45 / 252
# Fetching weather for Delaware State
# Fetching weather for school 46 / 252
# Fetching weather for Drake
# Fetching weather for school 47 / 252
# Fetching weather for Duke
# Fetching weather for school 48 / 252
# Fetching weather for Duquesne
# Fetching weather for school 49 / 252
# Fetching weather for East Carolina
# Fetching weather for school 50 / 252
# RESULTS:  50 0
# Fetching weather for East Tennessee State
# Fetching weather for school 51 / 252
# Fetching weather for East Texas A&M
# Fetching weather for school 52 / 252
# Fetching weather for Eastern Illinois
# Fetching weather for school 53 / 252
# Fetching weather for Eastern Kentucky
# Fetching weather for school 54 / 252
# Fetching weather for Eastern Michigan
# Fetching weather for school 55 / 252
# Fetching weather for Eastern Washington
# Fetching weather for school 56 / 252
# Fetching weather for Elon University
# Fetching weather for school 57 / 252
# Fetching weather for FIU
# Fetching weather for school 58 / 252
# Fetching weather for Florida
# Fetching weather for school 59 / 252
# Fetching weather for Florida A&M
# Fetching weather for school 60 / 252
# RESULTS:  60 0
# Fetching weather for Florida Atlantic
# Fetching weather for school 61 / 252
# Fetching weather for Florida State
# Fetching weather for school 62 / 252
# Fetching weather for Fordham
# Fetching weather for school 63 / 252
# Fetching weather for Fresno State
# Fetching weather for school 64 / 252
# Fetching weather for Furman
# Fetching weather for school 65 / 252
# Fetching weather for Gardner Webb
# Fetching weather for school 66 / 252
# Fetching weather for Georgia
# Fetching weather for school 67 / 252
# Fetching weather for Georgia Southern
# Fetching weather for school 68 / 252
# Fetching weather for Georgia State
# Fetching weather for school 69 / 252
# Fetching weather for Georgia Tech
# Fetching weather for school 70 / 252
# RESULTS:  70 0
# Fetching weather for Grambling State
# Fetching weather for school 71 / 252
# Fetching weather for Hampton
# Fetching weather for school 72 / 252
# Fetching weather for Hawaii
# Fetching weather for school 73 / 252
# Fetching weather for Hofstra
# Fetching weather for school 74 / 252
# Fetching weather for Holy Cross
# Fetching weather for school 75 / 252
# Fetching weather for Houston
# Fetching weather for school 76 / 252
# Fetching weather for Houston Baptist
# Fetching weather for school 77 / 252
# Fetching weather for Houston Christian
# Fetching weather for school 78 / 252
# Fetching weather for Howard
# Fetching weather for school 79 / 252
# Fetching weather for Idaho
# Fetching weather for school 80 / 252
# RESULTS:  80 0
# Fetching weather for Idaho State
# Fetching weather for school 81 / 252
# Fetching weather for Illinois
# Fetching weather for school 82 / 252
# Fetching weather for Illinois State
# Fetching weather for school 83 / 252
# Fetching weather for Incarnate Word
# Fetching weather for school 84 / 252
# Fetching weather for Indiana
# Fetching weather for school 85 / 252
# Fetching weather for Indiana State
# Fetching weather for school 86 / 252
# Fetching weather for Iowa
# Fetching weather for school 87 / 252
# Fetching weather for Iowa State
# Fetching weather for school 88 / 252
# Fetching weather for Jackson State
# Fetching weather for school 89 / 252
# Fetching weather for Jacksonville State
# Fetching weather for school 90 / 252
# RESULTS:  90 0
# Fetching weather for James Madison
# Fetching weather for school 91 / 252
# Fetching weather for Kansas
# Fetching weather for school 92 / 252
# Fetching weather for Kansas State
# Fetching weather for school 93 / 252
# Fetching weather for Kennesaw State
# Fetching weather for school 94 / 252
# Fetching weather for Kent State
# Fetching weather for school 95 / 252
# Fetching weather for Kentucky
# Fetching weather for school 96 / 252
# Fetching weather for LIU
# Fetching weather for school 97 / 252
# Fetching weather for LSU
# Fetching weather for school 98 / 252
# Fetching weather for Lafayette
# Fetching weather for school 99 / 252
# Fetching weather for Lamar
# Fetching weather for school 100 / 252
# RESULTS:  100 0
# Fetching weather for Lehigh
# Fetching weather for school 101 / 252
# Fetching weather for Liberty
# Fetching weather for school 102 / 252
# Fetching weather for Lindenwood
# Fetching weather for school 103 / 252
# Fetching weather for Louisiana Tech
# Fetching weather for school 104 / 252
# Fetching weather for Louisville
# Fetching weather for school 105 / 252
# Fetching weather for Maine
# Fetching weather for school 106 / 252
# Fetching weather for Marshall
# Fetching weather for school 107 / 252
# Fetching weather for Maryland
# Fetching weather for school 108 / 252
# Fetching weather for Massachusetts
# Fetching weather for school 109 / 252
# Fetching weather for McNeese State
# Fetching weather for school 110 / 252
# RESULTS:  110 0
# Fetching weather for Memphis
# Fetching weather for school 111 / 252
# Fetching weather for Mercer
# Fetching weather for school 112 / 252
# Fetching weather for Merrimack
# Fetching weather for school 113 / 252
# Fetching weather for Miami (FL)
# Fetching weather for school 114 / 252
# Fetching weather for Miami (OH)
# Fetching weather for school 115 / 252
# Fetching weather for Michigan
# Fetching weather for school 116 / 252
# Fetching weather for Michigan State
# Fetching weather for school 117 / 252
# Fetching weather for Middle Tennessee
# Fetching weather for school 118 / 252
# Fetching weather for Minnesota
# Fetching weather for school 119 / 252
# Fetching weather for Mississippi State
# Fetching weather for school 120 / 252
# RESULTS:  120 0
# Fetching weather for Mississippi Valley State
# Fetching weather for school 121 / 252
# Fetching weather for Missouri
# Fetching weather for school 122 / 252
# Fetching weather for Missouri State
# Fetching weather for school 123 / 252
# Fetching weather for Monmouth
# Fetching weather for school 124 / 252
# Fetching weather for Montana
# Fetching weather for school 125 / 252
# Fetching weather for Montana State
# Fetching weather for school 126 / 252
# Fetching weather for Morgan State
# Fetching weather for school 127 / 252
# Fetching weather for Murray State
# Fetching weather for school 128 / 252
# Fetching weather for NC State
# Fetching weather for school 129 / 252
# Fetching weather for Navy
# Fetching weather for school 130 / 252
# RESULTS:  130 0
# Fetching weather for Nebraska
# Fetching weather for school 131 / 252
# Fetching weather for Nevada
# Fetching weather for school 132 / 252
# Fetching weather for New Hampshire
# Fetching weather for school 133 / 252
# Fetching weather for New Mexico
# Fetching weather for school 134 / 252
# Fetching weather for New Mexico State
# Fetching weather for school 135 / 252
# Fetching weather for Nicholls State
# Fetching weather for school 136 / 252
# Fetching weather for Norfolk State
# Fetching weather for school 137 / 252
# Fetching weather for North Alabama
# Fetching weather for school 138 / 252
# Fetching weather for North Carolina
# Fetching weather for school 139 / 252
# Fetching weather for North Carolina A&T
# Fetching weather for school 140 / 252
# RESULTS:  140 0
# Fetching weather for North Carolina Central
# Fetching weather for school 141 / 252
# Fetching weather for North Dakota
# Fetching weather for school 142 / 252
# Fetching weather for North Dakota State
# Fetching weather for school 143 / 252
# Fetching weather for North Texas
# Fetching weather for school 144 / 252
# Fetching weather for Northeastern
# Fetching weather for school 145 / 252
# Fetching weather for Northern Arizona
# Fetching weather for school 146 / 252
# Fetching weather for Northern Colorado
# Fetching weather for school 147 / 252
# Fetching weather for Northern Illinois
# Fetching weather for school 148 / 252
# Fetching weather for Northern Iowa
# Fetching weather for school 149 / 252
# Fetching weather for Northwestern
# Fetching weather for school 150 / 252
# RESULTS:  150 0
# Fetching weather for Northwestern Oklahoma State
# Fetching weather for school 151 / 252
# Fetching weather for Northwestern State
# Fetching weather for school 152 / 252
# Fetching weather for Notre Dame
# Fetching weather for school 153 / 252
# Fetching weather for Ohio
# Fetching weather for school 154 / 252
# Fetching weather for Ohio State
# Fetching weather for school 155 / 252
# Fetching weather for Oklahoma
# Fetching weather for school 156 / 252
# Fetching weather for Oklahoma State
# Fetching weather for school 157 / 252
# Fetching weather for Old Dominion
# Fetching weather for school 158 / 252
# Fetching weather for Ole Miss
# Fetching weather for school 159 / 252
# Fetching weather for Oregon
# Fetching weather for school 160 / 252
# RESULTS:  160 0
# Fetching weather for Oregon State
# Fetching weather for school 161 / 252
# Fetching weather for Penn State
# Fetching weather for school 162 / 252
# Fetching weather for Pittsburgh
# Fetching weather for school 163 / 252
# Fetching weather for Portland State
# Fetching weather for school 164 / 252
# Fetching weather for Prairie View A&M
# Fetching weather for school 165 / 252
# Fetching weather for Presbyterian
# Fetching weather for school 166 / 252
# Fetching weather for Purdue
# Fetching weather for school 167 / 252
# Fetching weather for Rhode Island
# Fetching weather for school 168 / 252
# Fetching weather for Rice
# Fetching weather for school 169 / 252
# Fetching weather for Richmond
# Fetching weather for school 170 / 252
# RESULTS:  170 0
# Fetching weather for Robert Morris
# Fetching weather for school 171 / 252
# Fetching weather for Rutgers
# Fetching weather for school 172 / 252
# Fetching weather for SE Missouri State
# Fetching weather for school 173 / 252
# Fetching weather for SMU
# Fetching weather for school 174 / 252
# Fetching weather for Sacramento State
# Fetching weather for school 175 / 252
# Fetching weather for Sacred Heart
# Fetching weather for school 176 / 252
# Fetching weather for Sam Houston State
# Fetching weather for school 177 / 252
# Fetching weather for Samford
# Fetching weather for school 178 / 252
# Fetching weather for San Diego
# Fetching weather for school 179 / 252
# Fetching weather for San Diego State
# Fetching weather for school 180 / 252
# RESULTS:  180 0
# Fetching weather for San Jose State
# Fetching weather for school 181 / 252
# Fetching weather for Savannah State
# Fetching weather for school 182 / 252
# Fetching weather for South Alabama
# Fetching weather for school 183 / 252
# Fetching weather for South Carolina
# Fetching weather for school 184 / 252
# Fetching weather for South Carolina State
# Fetching weather for school 185 / 252
# Fetching weather for South Dakota
# Fetching weather for school 186 / 252
# Fetching weather for South Dakota State
# Fetching weather for school 187 / 252
# Fetching weather for Southeastern Louisiana
# Fetching weather for school 188 / 252
# Fetching weather for Southern
# Fetching weather for school 189 / 252
# Fetching weather for Southern Illinois
# Fetching weather for school 190 / 252
# RESULTS:  190 0
# Fetching weather for Southern Miss
# Fetching weather for school 191 / 252
# Fetching weather for Southern Utah
# Fetching weather for school 192 / 252
# Fetching weather for St. Francis (PA)
# Fetching weather for school 193 / 252
# Fetching weather for Stanford
# Fetching weather for school 194 / 252
# Fetching weather for Stephen F. Austin
# Fetching weather for school 195 / 252
# Fetching weather for Stony Brook
# Fetching weather for school 196 / 252
# Fetching weather for Syracuse
# Fetching weather for school 197 / 252
# Fetching weather for TCU
# Fetching weather for school 198 / 252
# Fetching weather for Tarleton State
# Fetching weather for school 199 / 252
# Fetching weather for Temple
# Fetching weather for school 200 / 252
# RESULTS:  200 0
# Fetching weather for Tennessee
# Fetching weather for school 201 / 252
# Fetching weather for Tennessee State
# Fetching weather for school 202 / 252
# Fetching weather for Tennessee Tech
# Fetching weather for school 203 / 252
# Fetching weather for Tennessee-Martin
# Fetching weather for school 204 / 252
# Fetching weather for Texas
# Fetching weather for school 205 / 252
# Fetching weather for Texas A&M
# Fetching weather for school 206 / 252
# Fetching weather for Texas A&M-Commerce
# Fetching weather for school 207 / 252
# Fetching weather for Texas Southern
# Fetching weather for school 208 / 252
# Fetching weather for Texas State
# Fetching weather for school 209 / 252
# Fetching weather for Texas Tech
# Fetching weather for school 210 / 252
# RESULTS:  210 0
# Fetching weather for Toledo
# Fetching weather for school 211 / 252
# Fetching weather for Towson
# Fetching weather for school 212 / 252
# Fetching weather for Troy
# Fetching weather for school 213 / 252
# Fetching weather for Tulane
# Fetching weather for school 214 / 252
# Fetching weather for Tulsa
# Fetching weather for school 215 / 252
# Fetching weather for UAB
# Fetching weather for school 216 / 252
# Fetching weather for UC-Davis
# Fetching weather for school 217 / 252
# Fetching weather for UCF
# Fetching weather for school 218 / 252
# Fetching weather for UCLA
# Fetching weather for school 219 / 252
# Fetching weather for UL-Lafayette
# Fetching weather for school 220 / 252
# RESULTS:  220 0
# Fetching weather for UL-Monroe
# Fetching weather for school 221 / 252
# Fetching weather for UNLV
# Fetching weather for school 222 / 252
# Fetching weather for USC
# Fetching weather for school 223 / 252
# Fetching weather for USF
# Fetching weather for school 224 / 252
# Fetching weather for UTEP
# Fetching weather for school 225 / 252
# Fetching weather for UTSA
# Fetching weather for school 226 / 252
# Fetching weather for Utah
# Fetching weather for school 227 / 252
# Fetching weather for Utah State
# Fetching weather for school 228 / 252
# Fetching weather for Utah Tech
# Fetching weather for school 229 / 252
# Fetching weather for Valparaiso
# Fetching weather for school 230 / 252
# RESULTS:  230 0
# Fetching weather for Vanderbilt
# Fetching weather for school 231 / 252
# Fetching weather for Villanova
# Fetching weather for school 232 / 252
# Fetching weather for Virginia
# Fetching weather for school 233 / 252
# Fetching weather for Virginia Military
# Fetching weather for school 234 / 252
# Fetching weather for Virginia Tech
# Fetching weather for school 235 / 252
# Fetching weather for Wagner
# Fetching weather for school 236 / 252
# Fetching weather for Wake Forest
# Fetching weather for school 237 / 252
# Fetching weather for Washington
# Fetching weather for school 238 / 252
# Fetching weather for Washington State
# Fetching weather for school 239 / 252
# Fetching weather for Weber State
# Fetching weather for school 240 / 252
# RESULTS:  240 0
# Fetching weather for West Virginia
# Fetching weather for school 241 / 252
# Fetching weather for Western Carolina
# Fetching weather for school 242 / 252
# Fetching weather for Western Illinois
# Fetching weather for school 243 / 252
# Fetching weather for Western Kentucky
# Fetching weather for school 244 / 252
# Fetching weather for Western Michigan
# Fetching weather for school 245 / 252
# Fetching weather for Western New Mexico
# Fetching weather for school 246 / 252
# Fetching weather for William & Mary
# Fetching weather for school 247 / 252
# Fetching weather for Wisconsin
# Fetching weather for school 248 / 252
# Fetching weather for Wofford
# Fetching weather for school 249 / 252
# Fetching weather for Wyoming
# Fetching weather for school 250 / 252
# RESULTS:  250 0
# Fetching weather for Yale
# Fetching weather for school 251 / 252
# Fetching weather for Youngstown State
# Fetching weather for school 252 / 252
