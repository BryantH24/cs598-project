# %% [markdown]
# Using Gemini LLM to Match Kaggle/ESPN API School Names to NCES/DoE School Names

# %%
import pandas as pd
import time
import os
from datetime import datetime

import sys
sys.path.append('..')
from utils.llm_utils import call_gemini_api

DELAY = 5 # seconds

# File paths
CFB_DATA_PATH = "../../college_football_data/cfb_box-scores_2002-2024_20251006_193644.csv"
NCES_DATA_PATH = "../../postsecondary_school_locations/postsecondary_school_locations_2020-21_20251006_194802.csv"
MATCHED_SCHOOLS_CSV = "../../intermediate_files/llm_matched_schools.csv"

# %% [markdown]
# Read files

# %%
nces_df = pd.read_csv(NCES_DATA_PATH)
nces_schools = nces_df['NAME'].tolist()
cfb_df = pd.read_csv(CFB_DATA_PATH)

cfb_schools = set(cfb_df['away'].dropna()) | set(cfb_df['home'].dropna())
cfb_schools = sorted(list(cfb_schools))

print(f"Unique school match count: {len(cfb_schools)}")
# Out:
# Unique school match count: 252

# %% [markdown]
# Get existing matches (for partial runs)

# %%
if os.path.exists(MATCHED_SCHOOLS_CSV):
    try:
        df = pd.read_csv(MATCHED_SCHOOLS_CSV)
        if len(df) > 0 and 'cfb_school' in df.columns and 'nces_name' in df.columns:
            existing_matches = dict(zip(df['cfb_school'], df['nces_name']))
    except Exception as e:
        existing_matches = {}
else:
    existing_matches = {}

# %% [markdown]
# Get list of schools to process

# %%
missing_schools = [school for school in cfb_schools if school not in existing_matches]
schools_to_process = [school for school, match in existing_matches.items()
                         if match in ["NO_MATCH", "API_ERROR"]]

if not schools_to_process:
    schools_to_process = [school for school in cfb_schools if school not in existing_matches]

# %% [markdown]
# LLM Prompt

# %%
def create_matching_prompt(cfb_school, nces_schools_list):
    sample_nces = nces_schools_list[:100]

    prompt = f"""You are a school name matching expert. I need you to find the best matching NCES school name or Department of Education school name for a college football team.

College Football Team: "{cfb_school}"

Here are some examples of NCES school names from the National Center for Education Statistics database:
{chr(10).join(f"- {school}" for school in sample_nces[:20])}

1. Look for the closest match between "{cfb_school}" and NCES school names
2. Consider common variations like:
   - "University" vs "College"
   - Abbreviations (State, A&M, etc.)
   - Location names
   - Ampersands (&) vs "and"
3. If you find a good match, return ONLY the exact NCES school name
4. If no good match exists, return "NO_MATCH"

Return your answer as a single line with just the NCES school name or "NO_MATCH".
Do not include any explanation or additional text."""

    return prompt

# %% [markdown]
# Gemini API Wrapping Function

# %%
def save_matches(matches_dict):
    df = pd.DataFrame(list(matches_dict.items()), columns=['cfb_school', 'nces_name'])
    # TODO: update the timestamp per row
    df['processed_date'] = datetime.now().isoformat()
    df.to_csv(MATCHED_SCHOOLS_CSV, index=False)
    print("Saved matches")


for i, cfb_school in enumerate(schools_to_process):
    print("Processing school " + cfb_school )

    prompt = create_matching_prompt(cfb_school, nces_schools)
    nces_match, _ = call_gemini_api(prompt)

    existing_matches[cfb_school] = nces_match

    print("Match: " + nces_match)
    print()

    save_matches(existing_matches)
    time.sleep(DELAY)

save_matches(existing_matches)
# Out:
# Processing school Georgia Southern
# Match: Georgia Southern University
#
# Saved matches
# Processing school Georgia State
# Match: Georgia State University
#
# Saved matches
# Processing school Georgia Tech
# Match: Georgia Institute of Technology-Main Campus
#
# Saved matches
# Processing school Grambling State
# Match: Grambling State University
#
# Saved matches
# Processing school Hampton
# Match: Hampton University
#
# Saved matches
# Processing school Hawaii
# Match: University of Hawaii at Manoa
#
# Saved matches
# Processing school Hofstra
# Match: Hofstra University
#
# Saved matches
# Processing school Holy Cross
# Match: College of the Holy Cross
#
# Saved matches
# Processing school Houston
# Match: University of Houston
#
# Saved matches
# Processing school Houston Baptist
# Match: Houston Baptist University
#
# Saved matches
# Processing school Houston Christian
# Match: Houston Christian University
#
# Saved matches
# Processing school Howard
# Match: Howard University
#
# Saved matches
# Processing school Idaho
# Match: University of Idaho
#
# Saved matches
# Processing school Idaho State
# Match: Idaho State University
#
# Saved matches
# Processing school Illinois
# Match: University of Illinois at Urbana-Champaign
#
# Saved matches
# Processing school Illinois State
# Match: Illinois State University
#
# Saved matches
# Processing school Incarnate Word
# Match: University of the Incarnate Word
#
# Saved matches
# Processing school Indiana
# Match: Indiana University-Bloomington
#
# Saved matches
# Processing school Indiana State
# Match: Indiana State University
#
# Saved matches
# Processing school Iowa
# Match: University of Iowa
#
# Saved matches
# Processing school Iowa State
# Match: Iowa State University
#
# Saved matches
# Processing school Jackson State
# Match: Jackson State University
#
# Saved matches
# Processing school Jacksonville State
# Match: Jacksonville State University
#
# Saved matches
# Processing school James Madison
# Match: James Madison University
#
# Saved matches
# Processing school Kansas
# Match: University of Kansas
#
# Saved matches
# Processing school Kansas State
# Match: Kansas State University
#
# Saved matches
# Processing school Kennesaw State
# Match: Kennesaw State University
#
# Saved matches
# Processing school Kent State
# Match: Kent State University at Kent
#
# Saved matches
# Processing school Kentucky
# Match: University of Kentucky
#
# Saved matches
# Processing school LIU
# Match: Long Island University
#
# Saved matches
# Processing school LSU
# Match: Louisiana State University and Agricultural & Mechanical College
#
# Saved matches
# Processing school Lafayette
# Match: Lafayette College
#
# Saved matches
# Processing school Lamar
# Match: Lamar University
#
# Saved matches
# Processing school Lehigh
# Match: Lehigh University
#
# Saved matches
# Processing school Liberty
# Match: Liberty University
#
# Saved matches
# Processing school Lindenwood
# Match: Lindenwood University
#
# Saved matches
# Processing school Louisiana Tech
# Match: Louisiana Tech University
#
# Saved matches
# Processing school Louisville
# Match: University of Louisville
#
# Saved matches
# Processing school Maine
# Match: University of Maine
#
# Saved matches
# Processing school Marshall
# Match: Marshall University
#
# Saved matches
# Processing school Maryland
# Match: University of Maryland-College Park
#
# Saved matches
# Processing school Massachusetts
# Match: University of Massachusetts-Amherst
#
# Saved matches
# Processing school McNeese State
# Match: McNeese State University
#
# Saved matches
# Processing school Memphis
# Match: University of Memphis
#
# Saved matches
# Processing school Mercer
# Match: Mercer University
#
# Saved matches
# Processing school Merrimack
# Match: Merrimack College
#
# Saved matches
# Processing school Miami (FL)
# Match: University of Miami
#
# Saved matches
# Processing school Miami (OH)
# Match: Miami University-Oxford
#
# Saved matches
# Processing school Michigan
# Match: University of Michigan-Ann Arbor
#
# Saved matches
# Processing school Michigan State
# Match: Michigan State University
#
# Saved matches
# Processing school Middle Tennessee
# Match: Middle Tennessee State University
#
# Saved matches
# Processing school Minnesota
# Match: University of Minnesota-Twin Cities
#
# Saved matches
# Processing school Mississippi State
# Match: Mississippi State University
#
# Saved matches
# Processing school Mississippi Valley State
# Match: Mississippi Valley State University
#
# Saved matches
# Processing school Missouri
# Match: University of Missouri-Columbia
#
# Saved matches
# Processing school Missouri State
# Match: Missouri State University-Springfield
#
# Saved matches
# Processing school Monmouth
# Match: Monmouth University
#
# Saved matches
# Processing school Montana
# Match: The University of Montana
#
# Saved matches
# Processing school Montana State
# Match: Montana State University
#
# Saved matches
# Processing school Morgan State
# Match: Morgan State University
#
# Saved matches
# Processing school Murray State
# Match: Murray State University
#
# Saved matches
# Processing school NC State
# Match: North Carolina State University at Raleigh
#
# Saved matches
# Processing school Navy
# Match: United States Naval Academy
#
# Saved matches
# Processing school Nebraska
# Match: University of Nebraska-Lincoln
#
# Saved matches
# Processing school Nevada
# Match: University of Nevada-Reno
#
# Saved matches
# Processing school New Hampshire
# Match: University of New Hampshire-Main Campus
#
# Saved matches
# Processing school New Mexico
# Match: University of New Mexico-Main Campus
#
# Saved matches
# Processing school New Mexico State
# Match: New Mexico State University-Main Campus
#
# Saved matches
# Processing school Nicholls State
# Match: Nicholls State University
#
# Saved matches
# Processing school Norfolk State
# Match: Norfolk State University
#
# Saved matches
# Processing school North Alabama
# Match: University of North Alabama
#
# Saved matches
# Processing school North Carolina
# Match: University of North Carolina at Chapel Hill
#
# Saved matches
# Processing school North Carolina A&T
# Match: North Carolina A & T State University
#
# Saved matches
# Processing school North Carolina Central
# Match: North Carolina Central University
#
# Saved matches
# Processing school North Dakota
# Match: University of North Dakota
#
# Saved matches
# Processing school North Dakota State
# Match: North Dakota State University-Main Campus
#
# Saved matches
# Processing school North Texas
# Match: University of North Texas
#
# Saved matches
# Processing school Northeastern
# Match: Northeastern University
#
# Saved matches
# Processing school Northern Arizona
# Match: Northern Arizona University
#
# Saved matches
# Processing school Northern Colorado
# Match: University of Northern Colorado
#
# Saved matches
# Processing school Northern Illinois
# Match: Northern Illinois University
#
# Saved matches
# Processing school Northern Iowa
# Match: University of Northern Iowa
#
# Saved matches
# Processing school Northwestern
# Match: Northwestern University
#
# Saved matches
# Processing school Northwestern Oklahoma State
# Match: Northwestern Oklahoma State University
#
# Saved matches
# Processing school Northwestern State
# Match: Northwestern State University of Louisiana
#
# Saved matches
# Processing school Notre Dame
# Match: University of Notre Dame
#
# Saved matches
# Processing school Ohio
# Match: Ohio University-Main Campus
#
# Saved matches
# Processing school Ohio State
# Match: Ohio State University-Main Campus
#
# Saved matches
# Processing school Oklahoma
# Match: University of Oklahoma-Norman Campus
#
# Saved matches
# Processing school Oklahoma State
# Match: Oklahoma State University-Main Campus
#
# Saved matches
# Processing school Old Dominion
# Match: Old Dominion University
#
# Saved matches
# Processing school Ole Miss
# Match: University of Mississippi
#
# Saved matches
# Processing school Oregon
# Match: University of Oregon
#
# Saved matches
# Processing school Oregon State
# Match: Oregon State University
#
# Saved matches
# Processing school Penn State
# Match: Pennsylvania State University-Main Campus
#
# Saved matches
# Processing school Pittsburgh
# Match: University of Pittsburgh-Pittsburgh Campus
#
# Saved matches
# Processing school Portland State
# Match: Portland State University
#
# Saved matches
# Processing school Prairie View A&M
# Match: Prairie View A & M University
#
# Saved matches
# Processing school Presbyterian
# Match: Presbyterian College
#
# Saved matches
# Processing school Purdue
# Match: Purdue University-Main Campus
#
# Saved matches
# Processing school Rhode Island
# Match: University of Rhode Island
#
# Saved matches
# Processing school Rice
# Match: Rice University
#
# Saved matches
# Processing school Richmond
# Match: University of Richmond
#
# Saved matches
# Processing school Robert Morris
# Match: Robert Morris University
#
# Saved matches
# Processing school Rutgers
# Match: Rutgers University-New Brunswick
#
# Saved matches
# Processing school SE Missouri State
# Match: Southeast Missouri State University
#
# Saved matches
# Processing school SMU
# Match: Southern Methodist University
#
# Saved matches
# Processing school Sacramento State
# Match: California State University-Sacramento
#
# Saved matches
# Processing school Sacred Heart
# Match: Sacred Heart University
#
# Saved matches
# Processing school Sam Houston State
# Match: Sam Houston State University
#
# Saved matches
# Processing school Samford
# Match: Samford University
#
# Saved matches
# Processing school San Diego
# Match: San Diego State University
#
# Saved matches
# Processing school San Diego State
# Match: San Diego State University
#
# Saved matches
# Processing school San Jose State
# Match: San Jose State University
#
# Saved matches
# Processing school Savannah State
# Match: Savannah State University
#
# Saved matches
# Processing school South Alabama
# Match: University of South Alabama
#
# Saved matches
# Processing school South Carolina
# Match: University of South Carolina-Columbia
#
# Saved matches
# Processing school South Carolina State
# Match: South Carolina State University
#
# Saved matches
# Processing school South Dakota
# Match: University of South Dakota
#
# Saved matches
# Processing school South Dakota State
# Match: South Dakota State University
#
# Saved matches
# Processing school Southeastern Louisiana
# Match: Southeastern Louisiana University
#
# Saved matches
# Processing school Southern
# Match: Southern University and A & M College
#
# Saved matches
# Processing school Southern Illinois
# Match: Southern Illinois University-Carbondale
#
# Saved matches
# Processing school Southern Miss
# Match: University of Southern Mississippi
#
# Saved matches
# Processing school Southern Utah
# Match: Southern Utah University
#
# Saved matches
# Processing school St. Francis (PA)
# Match: Saint Francis University
#
# Saved matches
# Processing school Stanford
# Match: Stanford University
#
# Saved matches
# Processing school Stephen F. Austin
# Match: Stephen F Austin State University
#
# Saved matches
# Processing school Stony Brook
# Match: Stony Brook University
#
# Saved matches
# Processing school Syracuse
# Match: Syracuse University
#
# Saved matches
# Processing school TCU
# Match: Texas Christian University
#
# Saved matches
# Processing school Tarleton State
# Match: Tarleton State University
#
# Saved matches
# Processing school Temple
# Match: Temple University
#
# Saved matches
# Processing school Tennessee
# Match: The University of Tennessee-Knoxville
#
# Saved matches
# Processing school Tennessee State
# Match: Tennessee State University
#
# Saved matches
# Processing school Tennessee Tech
# Match: Tennessee Technological University
#
# Saved matches
# Processing school Tennessee-Martin
# Match: The University of Tennessee-MartinThe University of Tennessee-Martin
#
# Saved matches
# Processing school Texas
# Match: The University of Texas at Austin
#
# Saved matches
# Processing school Texas A&M
# Match: Texas A & M University-College Station
#
# Saved matches
# Processing school Texas A&M-Commerce
# Match: Texas A & M University-Commerce
#
# Saved matches
# Processing school Texas Southern
# Match: Texas Southern University
#
# Saved matches
# Processing school Texas State
# Match: Texas State University
#
# Saved matches
# Processing school Texas Tech
# Match: Texas Tech University
#
# Saved matches
# Processing school Toledo
# Match: University of Toledo
#
# Saved matches
# Processing school Towson
# Match: Towson University
#
# Saved matches
# Processing school Troy
# Match: Troy University
#
# Saved matches
# Processing school Tulane
# Match: Tulane University of Louisiana
#
# Saved matches
# Processing school Tulsa
# Match: University of Tulsa
#
# Saved matches
# Processing school UAB
# Match: University of Alabama at Birmingham
#
# Saved matches
# Processing school UC-Davis
# Match: University of California-Davis
#
# Saved matches
# Processing school UCF
# Match: University of Central Florida
#
# Saved matches
# Processing school UCLA
# Match: University of California-Los Angeles
#
# Saved matches
# Processing school UL-Lafayette
# Match: University of Louisiana at Lafayette
#
# Saved matches
# Processing school UL-Monroe
# Match: University of Louisiana at Monroe
#
# Saved matches
# Processing school UNLV
# Match: University of Nevada-Las Vegas
#
# Saved matches
# Processing school USC
# Match: University of Southern California
#
# Saved matches
# Processing school USF
# Match: University of South Florida
#
# Saved matches
# Processing school UTEP
# Match: The University of Texas at El Paso
#
# Saved matches
# Processing school UTSA
# Match: The University of Texas at San Antonio
#
# Saved matches
# Processing school Utah
# Match: University of Utah
#
# Saved matches
# Processing school Utah State
# Match: Utah State University
#
# Saved matches
# Processing school Utah Tech
# Match: Utah Tech University
#
# Saved matches
# Processing school Valparaiso
# Match: Valparaiso University
#
# Saved matches
# Processing school Vanderbilt
# Match: Vanderbilt University
#
# Saved matches
# Processing school Villanova
# Match: Villanova University
#
# Saved matches
# Processing school Virginia
# Match: University of Virginia-Main Campus
#
# Saved matches
# Processing school Virginia Military
# Match: Virginia Military Institute
#
# Saved matches
# Processing school Virginia Tech
# Match: Virginia Polytechnic Institute and State University
#
# Saved matches
# Processing school Wagner
# Match: Wagner College
#
# Saved matches
# Processing school Wake Forest
# Match: Wake Forest University
#
# Saved matches
# Processing school Washington
# Match: University of Washington-Seattle Campus
#
# Saved matches
# Processing school Washington State
# Match: Washington State University
#
# Saved matches
# Processing school Weber State
# Match: Weber State University
#
# Saved matches
# Processing school West Virginia
# Match: West Virginia University
#
# Saved matches
# Processing school Western Carolina
# Match: Western Carolina University
#
# Saved matches
# Processing school Western Illinois
# Match: Western Illinois University
#
# Saved matches
# Processing school Western Kentucky
# Match: Western Kentucky University
#
# Saved matches
# Processing school Western Michigan
# Match: Western Michigan University
#
# Saved matches
# Processing school Western New Mexico
# Match: Western New Mexico University
#
# Saved matches
# Processing school William & Mary
# Match: William & Mary
#
# Saved matches
# Processing school Wisconsin
# Match: University of Wisconsin-Madison
#
# Saved matches
# Processing school Wofford
# Match: Wofford College
#
# Saved matches
# Processing school Wyoming
# Match: University of Wyoming
#
# Saved matches
# Processing school Yale
# Match: Yale University
#
# Saved matches
# Processing school Youngstown State
# Match: Youngstown State University
#
# Saved matches
# Saved matches
